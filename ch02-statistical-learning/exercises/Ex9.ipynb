# %% [markdown]
# # ISLP Chapter 2, Exercise 9
#
# Full solution for the Auto data set exercise (parts a-f).

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from ISLP import load_data
auto = load_data("auto")
